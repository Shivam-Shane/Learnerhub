# %% [markdown]
# ### iMPORTING ALL LIBRARIES

# %%
import pandas as pd
import numpy as np
from scipy import integrate
import seaborn as sns
import matplotlib.pyplot as mp
import plotly.offline as pyo
import plotly.graph_objs as go
import pandas_datareader as datareader
import datetime as datetime_module
import math
from sklearn.utils import shuffle
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Question 1

# %% [markdown]
#  In a survey conducted by a non-banking financial company, a sample of 200 customers yielded that x of them were highly satisfied with the timely disbursal of their loans.Write a Python code to perform the following operations:
#
#  1.Read an integer input thatspecifies the number of highly satisfied customers
#
#  2.Calculate an approximate 90% confidence interval for the proportion of the loan customers who are highly satisfied with disbursal time
#
#  •Find out the Margin of Error using scipy.stats.norm.ppf
#  •Calculate and print the confidence interval values rounded up to five decimal places and separated by a space
#  ##### Note:•Margin of Error = Critical Value * Standard Error of Statistic•Confidence Interval = Sample Statistic ± Margin of Error

# %%
x=int(input("enter the number of highly satsified customers"))
n=200
cl=0.90
point_estimate = x/n

print("number of highly satsified customers",x)
# Out:
# number of highly satsified customers 100

# %%
alpha = (1-cl)
critical_z = stats.norm.ppf(1-alpha/2)
S_error = math.sqrt((point_estimate*(1-point_estimate)/n))
margin_of_error = critical_z * S_error

print("Confidence interval",round((point_estimate - margin_of_error),5),round((point_estimate + margin_of_error),5))
# Out:
# Confidence interval 0.44185 0.55815

# %% [markdown]
# Question 2

# %% [markdown]
# A radar unit is used to measure the speeds of cars on a motorway. The speeds are normally distributed with a mean of 75 km/hr and a standard deviation of 15 km/hr.Write a Python code to perform the following operations
#
# ##### :1.Find theprobabilitythat a car picked at random is traveling at more thanXkm/hr•Take the speedXas an input•Printthe probability value rounded up tofour decimal places

# %%
### we have
mean=75
std=15
x=int(input("enter the number to find probabaility"))
number=x
# then z will be z=number-mean/ std
z=(number-mean)/std
## probablity of x > inpute number = p(z-1)
print("value of x ",x,"mean",mean,"std",std)
print("value of z",z)
## now p(x>inputednumber)=z-number from probabilty table
p=z-0.9515
print(p)
# Out:
# value of x  100 mean 75 std 15
# value of z 1.6666666666666667
# 0.7151666666666667

# %% [markdown]
# ##### Print the probability value rounded up tofour decimal places

# %%
print(round(p,4))
# Out:
# 0.7152

# %% [markdown]
# Question 3

# %% [markdown]
# Write a Python program toload the “kerala.csv”data into a DataFrameand perform the following tasks

# %% [markdown]
# Explore the DataFrame using info()and describe()functions2.June and July are the peak months of rainfall. Consider that if it rains more than 500mm, then chances of flood become more;create a Datarame with columns –“YEAR”, “JUN_GT_500”(Contains a boolean value to showwhether it rained more than500 mm in the month of June), “JUL_GT_500”(Contains a boolean value to showwhether it rained more than500 mm in the month of July),and “FLOODS”(Containsaboolean value to showwhetherit flooded that year)3.Calculate the probability of flood given it rained more than 500 mm in June (P(A|B))4.Calculate the probability of rain more than 500 mm in June,given it flooded that year (P(B|A))5.Probability of flood given it rained more than 500 mm in July6.Probability of rainmore than 500 mm in July given it flooded that year (P(B|A))

# %%
#importing the dataset from local drive
data=pd.read_csv('D:\Shane\study material\CSV\kerala.csv')

# %%
data
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
data.describe(include="all")
# Out:
#        SUBDIVISION         YEAR         JAN         FEB         MAR  \
# count          118   118.000000  118.000000  118.000000  118.000000
# unique           2          NaN         NaN         NaN         NaN
# top         KERALA          NaN         NaN         NaN         NaN
# freq           117          NaN         NaN         NaN         NaN
# mean           NaN  1959.500000   12.218644   15.633898   36.670339
# std            NaN    34.207699   15.473766   16.406290   30.063862
# min            NaN  1901.000000    0.000000    0.000000    0.100000
# 25%            NaN  1930.250000    2.175000    4.700000   18.100000
# 50%            NaN  1959.500000    5.800000    8.350000   28.400000
# 75%            NaN  1988.750000   18.175000   21.400000   49.825000
# max            NaN  2018.000000   83.500000   79.000000  217.200000
#
#                APR         MAY          JUN          JUL          AUG  \
# count   118.000000  118.000000   118.000000   118.000000   118.000000
# ...

# %%
data['SUBDIVISION'].value_counts()
# Out:
# KERALA     117
# KERALA       1
# Name: SUBDIVISION, dtype: int64

# %% [markdown]
# There must be a Type mistake in SubDivision ,Removing the column as its same for all the data.

# %%
data.drop(['SUBDIVISION'], inplace=True,axis=1)

# %%
data.set_index(data['YEAR'],inplace=True)
data.drop(['YEAR'],inplace=True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 1901 to 2018
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   JAN               118 non-null    float64
#  1   FEB               118 non-null    float64
#  2   MAR               118 non-null    float64
#  3   APR               118 non-null    float64
#  4   MAY               118 non-null    float64
#  5   JUN               118 non-null    float64
#  6   JUL               118 non-null    float64
#  7   AUG               118 non-null    float64
#  8   SEP               118 non-null    float64
#  9   OCT               118 non-null    float64
#  10  NOV               118 non-null    float64
#  11  DEC               118 non-null    float64
#  12   ANNUAL RAINFALL  118 non-null    float64
#  13  FLOODS            118 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 13.8+ KB

# %%
###our data does not conatain ant null values

# %%
data.head()
# Out:
#        JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG    SEP    OCT  \
# YEAR
# 1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5  197.7  266.9
# 1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8  491.6  358.4
# 1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2  341.8  354.1
# 1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8  222.7  328.1
# 1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6  217.2  383.5
#
#         NOV    DEC   ANNUAL RAINFALL FLOODS
# YEAR
# 1901  350.8   48.4            3248.6    YES
# 1902  158.3  121.5            3326.6    YES
# 1903  157.0   59.0            3271.2    YES
# 1904   33.9    3.3            3129.7    YES
# 1905   74.4    0.2            2741.6     NO

# %%
Size=data.columns[0:12]
mp.figure(figsize=(25,15))
for i in range(len(Size)):
    mp.plot(Size[i],data=data,label=Size[i])
    mp.legend()

# %%
Size=data.columns[0:12]

# %% [markdown]
# #### From the graph we can see that june and july are the peek months of raining

# %% [markdown]
# #### August was also at peek in 2022 for raining

# %%
data['JUN_GT_500']=np.where(data['JUN']>=500,1,0)
data['JUL_GT_500']=np.where(data['JUL']>=500,1,0)
data['FLOODS_']=np.where(data['FLOODS']>='YES',1,0)

# %%
data.head()
# Out:
#        JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG    SEP    OCT  \
# YEAR
# 1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5  197.7  266.9
# 1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8  491.6  358.4
# 1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2  341.8  354.1
# 1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8  222.7  328.1
# 1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6  217.2  383.5
#
#         NOV    DEC   ANNUAL RAINFALL FLOODS  JUN_GT_500  JUL_GT_500  FLOODS_
# YEAR
# 1901  350.8   48.4            3248.6    YES           1           1        1
# 1902  158.3  121.5            3326.6    YES           0           1        1
# 1903  157.0   59.0            3271.2    YES           1           1        1
# 1904   33.9    3.3            3129.7    YES           1           1        1
# 1905   74.4    0.2            2741.6     NO           1           1        0

# %%
data.drop(['FLOODS'],axis=1,inplace=True)

# %% [markdown]
# Adding one more column to make building a pivot table easier.

# %%
data['count']=1
pd.pivot_table(
    data, 
    values='count', 
    index=['FLOODS_'], 
    columns=['JUN_GT_500'], 
    aggfunc=np.size, 
    fill_value=0
)
# Out:
# JUN_GT_500   0   1
# FLOODS_
# 0           19  39
# 1            6  54

# %% [markdown]
# #### Calculate the probability of flood given it rained more than 500 mm in June (P(A|B))

# %%
p_a_flood=(6+54)/(39+54+19+6)#Probabilty of FLOOD
p_b_jun=(39+54)/(39+54+19+6)# Probabilty of  RAIN IN JUNE
p_a_jun_and_p_b_flood=54/(39+54+19+6)# Probabilty of  RAIN IN JUNE AND FLOODED THAT YEAR

# %%
p_flood_given_jun=p_a_jun_and_p_b_flood/p_b_jun
p_flood_given_jun
# Out:
# 0.5806451612903226

# %% [markdown]
# 4.Calculate the probability of rain more than 500 mm in June,given it flooded that year (P(B|A))

# %%
p_rain_given_floods=p_a_jun_and_p_b_flood/p_a_flood
p_rain_given_floods
# Out:
# 0.9

# %%
pd.pivot_table(
    data, 
    values='count', 
    index=['FLOODS_'], 
    columns=['JUL_GT_500'], 
    aggfunc=np.size, 
    fill_value=0
)
# Out:
# JUL_GT_500   0   1
# FLOODS_
# 0           19  39
# 1            3  57

# %%
p_a_flood=(3+57)/(39+57+19+3)# Probabilty of flood
p_b_jul=(39+57)/(39+57+19+3)#Probabilty of rain in july
p_a_jul_and_p_b_flood=54/(39+57+19+3)# Probabilty of rain in july and flooded year

# %% [markdown]
# Probability of flood given it rained more than 500 mm in July

# %%
p_flood_given_jul=p_a_jul_and_p_b_flood/p_b_jul
p_flood_given_jul
# Out:
# 0.5625

# %% [markdown]
# 6.Probability of rainmore than 500 mm in July given it flooded that year (P(B|A))

# %%
p_flood_given_jul=p_a_jul_and_p_b_flood/p_a_flood
p_flood_given_jul
# Out:
# 0.9

# %% [markdown]
# Question 4

# %% [markdown]
# Write a Python program to load the wine dataset using the Sklearn library to a DataFrame and perform the following tasks
# :1.Convert the datasetinto DataFrameusing pandas.
#
# 2.Generate the sample size of 50and givea randomstate as 100.
#
# 3.Calculate Z-critical, Margin of Error,andConfidence Interval for alcohol at 95% significance interval on generated sample data

# %%
from sklearn.datasets import load_wine

# %%
data2 = load_wine()
x,y=shuffle(data2.data,data2.target,random_state=4)
data3=pd.DataFrame(data2.data,columns=data2['feature_names'])

# %% [markdown]
# ### AS WE ARE ONLY CONCERNED HERE FOR ALCOHOL WE ARE NOT ADDING OUR TARGET COLUMN TO OUR DATAFRAME

# %%
data3.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
data3.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# #### Calculate Z-critical, Margin of Error,andConfidence Interval for alcohol at 95% significance interval on generated sample data.

# %% [markdown]
# ### 100 sample size

# %%
sample=data3.sample(n=50,random_state=100).alcohol
sample_mean=sample.mean()
sample_std=sample.std()
print("Sample mean and STD")
sample_mean,sample_std
# Out:
# Sample mean and STD
# (12.9736, 0.7686663775657162)

# %%
print("population mean and std: 13.000618 , 0.811827")
# Out:
# population mean and std: 13.000618 , 0.811827

# %% [markdown]
# null H: poulation mean = sample mean
# h0 : both are not same

# %%
from scipy import stats
from statsmodels.stats import weightstats as stests

# %%
sample.describe()
# Out:
# count    50.000000
# mean     12.973600
# std       0.768666
# min      11.640000
# 25%      12.290000
# 50%      12.915000
# 75%      13.550000
# max      14.380000
# Name: alcohol, dtype: float64

# %%
Z_critical=stats.norm.ppf(q=0.975)# zcrtical at 95% confidence
margin=Z_critical*(0.768666/np.sqrt(50))
ci=(12.973600-margin,12.973600+margin)
print("Z_critical ",Z_critical,"Margin of error",margin,"confidence interval ",ci)
# Out:
# Z_critical  1.959963984540054 Margin of error 0.21305942980951387 confidence interval  (12.760540570190486, 13.186659429809513)

# %% [markdown]
# https://github.com/Shanezatch/Learnerhub/blob/d8637725840088101cf793afc54fae99b03b822b/IPYTHON/Assignment%203.ipynb

# %%
#### END OF ASSIGNMENT
