# %%
import pandas as pd
import numpy as np
from scipy import integrate
import seaborn as sns
import matplotlib.pyplot as mp
import plotly.offline as pyo
import plotly.graph_objs as go
import pandas_datareader as datareader
import datetime as datetime_module
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('D:\Shane\study material\CSV\kerala.csv')

# %%
data
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
data.describe(include="all")
# Out:
#        SUBDIVISION         YEAR         JAN         FEB         MAR  \
# count          118   118.000000  118.000000  118.000000  118.000000
# unique           2          NaN         NaN         NaN         NaN
# top         KERALA          NaN         NaN         NaN         NaN
# freq           117          NaN         NaN         NaN         NaN
# mean           NaN  1959.500000   12.218644   15.633898   36.670339
# std            NaN    34.207699   15.473766   16.406290   30.063862
# min            NaN  1901.000000    0.000000    0.000000    0.100000
# 25%            NaN  1930.250000    2.175000    4.700000   18.100000
# 50%            NaN  1959.500000    5.800000    8.350000   28.400000
# 75%            NaN  1988.750000   18.175000   21.400000   49.825000
# max            NaN  2018.000000   83.500000   79.000000  217.200000
#
#                APR         MAY          JUN          JUL          AUG  \
# count   118.000000  118.000000   118.000000   118.000000   118.000000
# ...

# %%
data['SUBDIVISION'].value_counts()
# Out:
# KERALA     117
# KERALA       1
# Name: SUBDIVISION, dtype: int64

# %% [markdown]
# There must be a Type mistake in SubDivision ,Removing the column as its is same for all the data.

# %%
data.drop(['SUBDIVISION'], inplace=True,axis=1)

# %%
data.set_index(data['YEAR'],inplace=True)
data.drop(['YEAR'],inplace=True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 1901 to 2018
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   JAN               118 non-null    float64
#  1   FEB               118 non-null    float64
#  2   MAR               118 non-null    float64
#  3   APR               118 non-null    float64
#  4   MAY               118 non-null    float64
#  5   JUN               118 non-null    float64
#  6   JUL               118 non-null    float64
#  7   AUG               118 non-null    float64
#  8   SEP               118 non-null    float64
#  9   OCT               118 non-null    float64
#  10  NOV               118 non-null    float64
#  11  DEC               118 non-null    float64
#  12   ANNUAL RAINFALL  118 non-null    float64
#  13  FLOODS            118 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 13.8+ KB

# %%
###our data does not conatain ant null values

# %%
data
# Out:
#        JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP    OCT  \
# YEAR
# 1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7  266.9
# 1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6  358.4
# 1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8  354.1
# 1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7  328.1
# 1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2  383.5
# ...    ...   ...   ...    ...    ...     ...     ...     ...    ...    ...
# 2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8  355.5
# 2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9  308.1
# 2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2  225.9
# 2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5  192.4
# 2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6  356.1
#
#         NOV    DEC   ANNUAL RAINFALL FLOODS
# YEAR
# ...

# %%
data.iloc[:,0:12]
# Out:
#        JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP    OCT  \
# YEAR
# 1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7  266.9
# 1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6  358.4
# 1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8  354.1
# 1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7  328.1
# 1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2  383.5
# ...    ...   ...   ...    ...    ...     ...     ...     ...    ...    ...
# 2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8  355.5
# 2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9  308.1
# 2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2  225.9
# 2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5  192.4
# 2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6  356.1
#
#         NOV    DEC
# YEAR
# 1901  350.8   48.4
# ...

# %%
mp.plot(data['FLOODS'])
mp.plot(data['JUL'],color='red')

# %%
sns.histplot(data['FLOODS'])
# Out:
# <AxesSubplot:xlabel='FLOODS', ylabel='Count'>

# %%
x=172
n=200
p=x/n
q=1-p
z=1.645
print(x,n,p,q,z)
# Out:
# 172 200 0.86 0.14 1.645

# %%
p-(z*(np.sqrt((p*q)/n)))
# Out:
# 0.8196387927583924

# %%
p+(z*(np.sqrt((p*q)/n)))
# Out:
# 0.9003612072416076
