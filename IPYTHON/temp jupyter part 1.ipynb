# %%
import pandas as pn 
raw=pn.read_csv("1. Regression - Module - (Housing Prices).csv")
import matplotlib.pyplot as mp
mp.plot(raw['Sale Price'], color="red")
mp.xlabel("Record number ")
mp.ylabel("Shop price")
mp.title("house price graph")
mp.show()
