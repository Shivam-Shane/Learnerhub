# %%
import pandas as pd
import numpy as np 
import scipy as sp
import matplotlib.pyplot as mat

# %%
import seaborn as sns

# %%
data=pd.read_csv("F:\Adobe Photoshop CS6 Extended + Crack full version\programs\python and machine learning\data.csv")

# %%
data
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
#data=data.drop(["Unnamed: 0"],axis="columns")
data
# Out:
#       acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0          0.01020         0.833       204600   0.434          0.021900    2
# 1          0.19900         0.743       326933   0.359          0.006110    1
# 2          0.03440         0.838       185707   0.412          0.000234    2
# 3          0.60400         0.494       199413   0.338          0.510000    5
# 4          0.18000         0.678       392893   0.561          0.512000    5
# ...            ...           ...          ...     ...               ...  ...
# 2012       0.00106         0.584       274404   0.932          0.002690    1
# 2013       0.08770         0.894       182182   0.892          0.001670    1
# 2014       0.00857         0.637       207200   0.935          0.003990    0
# 2015       0.00164         0.557       185600   0.992          0.677000    1
# 2016       0.00281         0.446       204520   0.915          0.000039    9
#
# ...

# %%
#data=data.drop("artist",axis="columns")

# %%
#data=data.drop("song_title",axis="columns")

# %%
#data=data.drop("acousticness",axis="columns")
#data=data.drop("danceability",axis="columns")
#data=data.drop("tempo",axis="columns")

# %%
data
# Out:
#       duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0          204600   0.434          0.021900    2    0.1650    -8.795     1
# 1          326933   0.359          0.006110    1    0.1370   -10.401     1
# 2          185707   0.412          0.000234    2    0.1590    -7.148     1
# 3          199413   0.338          0.510000    5    0.0922   -15.236     1
# 4          392893   0.561          0.512000    5    0.4390   -11.648     0
# ...           ...     ...               ...  ...       ...       ...   ...
# 2012       274404   0.932          0.002690    1    0.1290    -3.501     1
# 2013       182182   0.892          0.001670    1    0.0528    -2.663     1
# 2014       207200   0.935          0.003990    0    0.2140    -2.467     1
# 2015       185600   0.992          0.677000    1    0.0913    -2.735     1
# 2016       204520   0.915          0.000039    9    0.2180    -6.221     1
#
#       speechiness  time_signature  valence  target
# ...

# %%
data.corr()
# Out:
#                   duration_ms    energy  instrumentalness       key  liveness  \
# duration_ms          1.000000 -0.144473          0.305403  0.023570  0.023203
# energy              -0.144473  1.000000         -0.122890  0.072886  0.217435
# instrumentalness     0.305403 -0.122890          1.000000 -0.009640  0.001063
# key                  0.023570  0.072886         -0.009640  1.000000  0.049739
# liveness             0.023203  0.217435          0.001063  0.049739  1.000000
# loudness            -0.273798  0.762177         -0.354625  0.050929  0.156648
# mode                -0.074806 -0.070263         -0.030099 -0.195040 -0.018587
# speechiness         -0.079562  0.093102         -0.155349  0.019116  0.092403
# time_signature      -0.040157  0.182895         -0.070721  0.024937  0.018199
# valence             -0.120030  0.278383         -0.194630  0.032485 -0.053011
# target               0.146749  0.039688          0.152594  0.033594  0.026364
#
# ...

# %%
mat.bar(data["loudness"],data["target"])
# Out:
# <BarContainer object of 2017 artists>
